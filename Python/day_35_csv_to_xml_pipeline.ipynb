# %% [markdown]
# # Dzień 35 - CSV → XML: przygotowanie pipeline

# %% [markdown]
# ## Zadanie 1 - Schemat konwersji danych
#
# Proces konwersji danych:
# CSV -> DataFrame -> lista słowników -> XML -> plik XML

# %%
etapy = [
    "CSV",
    "DataFrame",
    "lista słowników",
    "XML",
    "plik XML"
]

print(" -> ".join(etapy))
# Out:
# CSV -> DataFrame -> lista słowników -> XML -> plik XML
