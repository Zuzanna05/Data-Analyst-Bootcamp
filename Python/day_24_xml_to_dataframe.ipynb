# %% [markdown]
# # Dzień 24 - XML: konwersja danych do Pandas DataFrame
#
# ## Zakres
# - utworzenie DataFrame na podstawie danych odczytanych z XML

# %% [markdown]
# ## Zadanie 1 - Tworzenie DataFrame z danych XML

# %%
lista_produktow = [
    {"id": "1", "nazwa": "Laptop", "cena": "3499.99"},
    {"id": "2", "nazwa": "Monitor", "cena": "899.99"},
    {"id": "3", "nazwa": "Klawiatura", "cena": "249.90"}
]

import pandas as pd
df_produkty = pd.DataFrame(lista_produktow)
df_produkty
# Out:
#   id       nazwa     cena
# 0  1      Laptop  3499.99
# 1  2     Monitor   899.99
# 2  3  Klawiatura   249.90
