# %% [markdown]
# # Dzień 28 - XML: tworzenie elementu w Pythonie

# %% [markdown]
# ## Zadanie 1 - Utworzenie głównego elementu XML

# %%
import xml.etree.ElementTree as ET
root = ET.Element("produkty")
print(root.tag)
# Out:
# produkty
