# %% [markdown]
# # Dzień 27 - CSV i Pandas: konwersja danych do struktur Pythona
#
# ## Zakres
# - wczytanie pliku CSV do DataFrame
# - kontrola wczytanych danych
# - konwersja DataFrame do listy słowników
# - przygotowanie danych do późniejszego utworzenia XML

# %% [markdown]
# ## Zadanie 1 - Wczytanie danych CSV do DataFrame

# %%
import pandas as pd
df_produkty = pd.read_csv("data/produkty_z_xml.csv")
df_produkty
# Out:
#    id       nazwa     cena
# 0   1      Laptop  3499.99
# 1   2     Monitor   899.99
# 2   3  Klawiatura   249.90

# %% [markdown]
# ## Zadanie 2 - Konwersja DataFrame do listy słowników

# %%
lista_produktow = df_produkty.to_dict(orient = "records")
lista_produktow
# Out:
# [{'id': 1, 'nazwa': 'Laptop', 'cena': 3499.99},
#  {'id': 2, 'nazwa': 'Monitor', 'cena': 899.99},
#  {'id': 3, 'nazwa': 'Klawiatura', 'cena': 249.9}]

# %% [markdown]
# ## Zadanie 3 - Odczyt danych z listy słowników

# %%
lista_produktow[0]
lista_produktow[1]["cena"]
# Out:
# 899.99
